# %%
import numpy as np
import pandas as pd
from pathlib import Path
from typing import Dict, Tuple, List
from IPython.display import display
import re, os

from sklearn.metrics import roc_auc_score, average_precision_score, confusion_matrix
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier

try:
    from xgboost import XGBClassifier
    HAS_XGB = True
except Exception:
    HAS_XGB = False

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "4_class_balance").exists():
    parent = PROJECT_ROOT.parent
    if (parent / "4_class_balance").exists():
        PROJECT_ROOT = parent
    else:
        raise RuntimeError(f"Cannot find '4_class_balance' folder from cwd={Path.cwd()}")

# config 
LABEL_COL = "Is_Suspicious"
SCENARIO_COL = "Suspicion Category"
VARIANT_ROOTS: Dict[str, Path] = {
    "baseline": PROJECT_ROOT / "4_class_balance" / "baseline_500",
    "smote":    PROJECT_ROOT / "4_class_balance" / "smote_500",
    "adasyn":   PROJECT_ROOT / "4_class_balance" / "adasyn_500",
    "rose":     PROJECT_ROOT / "4_class_balance" / "rose_500",
}

VARIANT_TRAIN_FILE = {
    "baseline": "train_baseline.csv",
    "smote":    "train_smote.csv",
    "adasyn":   "train_adasyn.csv",
    "rose":     "train_rose.csv",
}
ALGOS = ["GBM", "XGB", "RF"]
TARGET_RECALL = 0.98
RANDOM_STATE = 42


WAVE_FILTER = None  

# helpers

def list_waves(root: Path) -> List[str]:
    if not root.exists():
        return []
    waves = sorted([p.name for p in root.iterdir() if p.is_dir()])
    return waves


def _resolve_train_path(dir_path: Path, variant: str) -> Path:
    """Return the first existing train file path for a variant within dir_path."""
    primary = dir_path / VARIANT_TRAIN_FILE[variant]
    if primary.exists():
        return primary
    fallback = dir_path / "train.csv"
    if fallback.exists():
        return fallback
    return primary  

def load_split(variant: str, wave: str) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    root = VARIANT_ROOTS[variant]
    d = root / wave
    train_path = _resolve_train_path(d, variant)
    test_path  = d / "test.csv"
    if not train_path.exists() or not test_path.exists():
        raise FileNotFoundError(f"Missing files for {variant}/{wave} → {train_path} / {test_path}")

    tr = pd.read_csv(train_path)
    te = pd.read_csv(test_path)

    if LABEL_COL not in tr.columns or LABEL_COL not in te.columns:
        raise KeyError(f"Column '{LABEL_COL}' not found in train/test for {variant}/{wave}")

    y_tr = tr[LABEL_COL].astype(int).to_numpy()
    y_te = te[LABEL_COL].astype(int).to_numpy()

    drop_cols = [LABEL_COL]
    if SCENARIO_COL in tr.columns:
        drop_cols.append(SCENARIO_COL)

    X_tr_df = tr.drop(columns=drop_cols).copy()
    X_te_df = te.drop(columns=drop_cols).copy()

    obj_cols_tr = list(X_tr_df.select_dtypes(include="object").columns)
    obj_cols_te = list(X_te_df.select_dtypes(include="object").columns)
    if obj_cols_tr or obj_cols_te:
        for c in obj_cols_tr:
            X_tr_df[c] = X_tr_df[c].fillna("NA").astype(str)
        for c in obj_cols_te:
            X_te_df[c] = X_te_df[c].fillna("NA").astype(str)

        X_tr_df = pd.get_dummies(X_tr_df)
        X_te_df = pd.get_dummies(X_te_df)
        X_tr_df, X_te_df = X_tr_df.align(X_te_df, join="outer", axis=1, fill_value=0)

    return X_tr_df.to_numpy(), y_tr, X_te_df.to_numpy(), y_te

def make_model(algo: str, y_tr: np.ndarray):
    if algo == "GBM":
        return GradientBoostingClassifier(
            n_estimators=300, learning_rate=0.05, max_depth=3, random_state=RANDOM_STATE
        )
    elif algo == "XGB" and HAS_XGB:
        pos = max(1, int((y_tr == 1).sum()))
        neg = max(1, int((y_tr == 0).sum()))
        spw = neg / pos
        return XGBClassifier(
            n_estimators=400, max_depth=4, learning_rate=0.05,
            subsample=0.8, colsample_bytree=0.8,
            reg_lambda=1.0, random_state=RANDOM_STATE,
            eval_metric="logloss", n_jobs=-1, tree_method="hist",
            scale_pos_weight=spw
        )
    elif algo == "RF":
        return RandomForestClassifier(
            n_estimators=300, max_depth=None, min_samples_leaf=1,
            class_weight="balanced", random_state=RANDOM_STATE, n_jobs=-1
        )
    else:
        raise RuntimeError("XGBoost not installed. Either install xgboost or remove 'XGB' from ALGOS.")


def threshold_for_recall(y_true: np.ndarray, scores: np.ndarray, target: float):
    order = np.argsort(-scores)
    y_sorted = y_true[order]
    s_sorted = scores[order]
    P = int(y_true.sum())
    if P == 0:
        return 1.0, {"precision": 0.0, "recall": 0.0, "tp": 0, "fp": 0, "tn": int((y_true==0).sum()), "fn": 0}
    tp_cum = np.cumsum(y_sorted)
    fp_cum = np.cumsum(1 - y_sorted)
    recall_cum = tp_cum / (P + 1e-12)
    idx = np.where(recall_cum >= target)[0]
    if len(idx) == 0:
        thr = s_sorted[-1] - 1e-12
        pred = np.ones_like(y_true)
    else:
        k = int(idx[0])
        thr = s_sorted[k]
        pred = (scores >= thr).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, pred, labels=[0,1]).ravel()
    prec = tp / max(1, tp + fp)
    rec  = tp / max(1, P)
    return float(thr), {"precision": float(prec), "recall": float(rec), "tp": int(tp), "fp": int(fp), "tn": int(tn), "fn": int(fn)}

# main comparison

def run_comparison():
    print("ROOTS:", {k: str(v) for k,v in VARIANT_ROOTS.items()})
    waves = list_waves(VARIANT_ROOTS["baseline"]) or []
    if WAVE_FILTER is not None:
        waves = [w for w in waves if WAVE_FILTER(w)]
    assert waves, "No waves found in baseline. Make sure you generated features/balanced sets first."
    print(f"Detected {len(waves)} wave(s): {waves}")

    rows = []
    thr_col = f"thr@R>={TARGET_RECALL:.2f}"

    for variant in ["baseline","smote","adasyn","rose"]:
        for wave in waves:
            try:
                X_tr, y_tr, X_te, y_te = load_split(variant, wave)
            except (FileNotFoundError, KeyError) as e:
                print(f"[skip] {e}")
                continue

            for algo in ALGOS:
                if algo == "XGB" and not HAS_XGB:
                    print("[warn] xgboost not installed, skipping XGB")
                    continue

                model = make_model(algo, y_tr)

                # sample weights for GBM (RF uses class_weight, XGB uses scale_pos_weight)
                sw = None
                if algo == "GBM":
                    n_pos = max(1, int((y_tr == 1).sum()))
                    n_neg = max(1, int((y_tr == 0).sum()))
                    w_pos = n_neg / (n_pos + n_neg)
                    w_neg = n_pos / (n_pos + n_neg)
                    sw = np.where(y_tr == 1, w_pos, w_neg)

                model.fit(X_tr, y_tr, sample_weight=sw) if sw is not None else model.fit(X_tr, y_tr)

                # probabilities for positive class
                if hasattr(model, "predict_proba"):
                    p = model.predict_proba(X_te)[:, 1]
                else:
                    try:
                        dec = model.decision_function(X_te)
                        p = (dec - dec.min()) / (dec.max() - dec.min() + 1e-12)
                    except Exception:
                        p = model.predict(X_te).astype(float)

                roc = roc_auc_score(y_te, p)
                prc = average_precision_score(y_te, p)
                thr, at = threshold_for_recall(y_te, p, TARGET_RECALL)
                n_test = len(y_te)
                fp_per_1000 = at["fp"] / max(1, n_test) * 1000.0

                rows.append({
                    "wave": wave,
                    "variant": variant,
                    "algo": algo,
                    "roc_auc": roc,
                    "pr_auc": prc,
                    "thr_col": thr,
                    "precision@R": at["precision"],
                    "recall@thr": at["recall"],
                    "TP": at["tp"],
                    "FP": at["fp"],
                    "TN": at["tn"],
                    "FN": at["fn"],
                    "FP_per_1000": fp_per_1000,
                    "n_test": n_test,
                })

    res = pd.DataFrame(rows)
    if res.empty:
        print("No rows produced: check file names/paths and LABEL_COL. See ROOTS/Detected waves above.")
        return

    out_dir = Path("./out_compare_500"); out_dir.mkdir(exist_ok=True, parents=True)
    res.to_csv(out_dir / "results_by_wave.csv", index=False)

    # summary
    def agg(df):
        return pd.Series({
            "waves": len(df),
            "roc_auc_mean": df["roc_auc"].mean(),
            "pr_auc_mean": df["pr_auc"].mean(),
            "precision@R_mean": df["precision@R"].mean(),
            "recall@thr_mean": df["recall@thr"].mean(),
            "FP_per_1000_mean": df["FP_per_1000"].mean(),
        })

    summary = res.groupby(["variant","algo"]).apply(agg).reset_index()
    summary.to_csv(out_dir / "summary.csv", index=False)

    # Precision/Recall
    pr_focus = summary[[
        "variant","algo","precision@R_mean","recall@thr_mean",
        "FP_per_1000_mean","pr_auc_mean","roc_auc_mean","waves"
    ]].sort_values(["precision@R_mean","recall@thr_mean"], ascending=[False, False])
    pr_focus.to_csv(out_dir / "precision_recall_summary.csv", index=False)

    # confusion matrices 
    conf_dir = out_dir / "conf_matrices"; conf_dir.mkdir(exist_ok=True, parents=True)
    def _sanitize(s: str) -> str:
        return str(s).replace("/","_").replace("\\","_").replace(" ","_")
    for _, r in res.iterrows():
        cm = pd.DataFrame([[int(r["TN"]), int(r["FP"])],[int(r["FN"]), int(r["TP"])]] ,
                          columns=["Pred=0","Pred=1"], index=["True=0","True=1"])
        fname = f"cm_{_sanitize(r['variant'])}_{_sanitize(r['algo'])}_{_sanitize(r['wave'])}.csv"
        cm.to_csv(conf_dir / fname)

    # progress tables
    progress_dir = out_dir / "progress_by_wave"; progress_dir.mkdir(exist_ok=True, parents=True)
    cols = ["wave","precision@R","recall@thr","FP_per_1000","TP","FP","TN","FN"]

    def _wave_key(w):
        m = re.search(r"(\d+)$", str(w))
        return (0, int(m.group(1))) if m else (1, str(w))

    for algo in ["GBM","XGB","RF"]:
        for variant in ["baseline","smote","adasyn","rose"]:
            dfv = res[(res["algo"]==algo) & (res["variant"]==variant)].copy()
            if dfv.empty:
                continue
            dfv = dfv.sort_values("wave", key=lambda s: s.map(_wave_key))
            dfv[cols].to_csv(progress_dir / f"progress_{algo}_{variant}.csv", index=False)

    # Stability report (mean/std/min/max)
    stab = (
        res.groupby(["variant","algo"])[["precision@R","FP_per_1000","pr_auc","roc_auc"]]
          .agg(["mean","std","min","max"]).reset_index()
    )
    # flatten MultiIndex columns
    stab.columns = ["variant","algo"] + ["_".join(col).strip() for col in stab.columns[2:].to_flat_index()]
    stab = stab.sort_values(["algo","variant"])
    stab.to_csv(out_dir / "stability_over_waves.csv", index=False)

    # print
    with pd.option_context("display.max_rows", 200, "display.max_columns", 50):
        print("\n=== SUMMARY (avg over waves) ===")
        display(summary.sort_values(["algo","variant"]))
        print("\n=== PRIMARY KPIs (Precision/Recall focus, sorted) ===")
        display(pr_focus)
        print("\nSaved:", str(out_dir / "results_by_wave.csv"), ",",
              str(out_dir / "summary.csv"), ",",
              str(out_dir / "precision_recall_summary.csv"))
        print("Confusion matrices saved to:", str(conf_dir))
        print("Per-wave progress saved to:", str(progress_dir))
        print("Stability report saved to:", str(out_dir / "stability_over_waves.csv"))

run_comparison()
# Out:
# ROOTS: {'baseline': 'c:\\Users\\T470s\\Documents\\GitHub\\Automated-Risk-Scoring-System\\4_class_balance\\baseline_500', 'smote': 'c:\\Users\\T470s\\Documents\\GitHub\\Automated-Risk-Scoring-System\\4_class_balance\\smote_500', 'adasyn': 'c:\\Users\\T470s\\Documents\\GitHub\\Automated-Risk-Scoring-System\\4_class_balance\\adasyn_500', 'rose': 'c:\\Users\\T470s\\Documents\\GitHub\\Automated-Risk-Scoring-System\\4_class_balance\\rose_500'}
# Detected 5 wave(s): ['synthetic_transactions_structured_500_1', 'synthetic_transactions_structured_500_2', 'synthetic_transactions_structured_500_3', 'synthetic_transactions_structured_500_4', 'synthetic_transactions_structured_500_5']
#
# === SUMMARY (avg over waves) ===
# C:\Users\T470s\AppData\Local\Temp\ipykernel_21164\1695389693.py:244: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   summary = res.groupby(["variant","algo"]).apply(agg).reset_index()
#      variant algo  waves  roc_auc_mean  pr_auc_mean  precision@R_mean  \
# 0     adasyn  GBM    5.0      0.736508     0.348988          0.052438
# 3   baseline  GBM    5.0      0.832055     0.452173          0.069466
# 6       rose  GBM    5.0      0.829208     0.470713          0.065983
# 9      smote  GBM    5.0      0.758657     0.398026          0.053597
# 1     adasyn   RF    5.0      0.733585     0.384651          0.050037
# 4   baseline   RF    5.0      0.787277     0.443715          0.052153
# 7       rose   RF    5.0      0.788815     0.446603          0.050682
# 10     smote   RF    5.0      0.731057     0.417439          0.050111
# 2     adasyn  XGB    5.0      0.801422     0.441455          0.057546
# 5   baseline  XGB    5.0      0.831669     0.467133          0.068188
# 8       rose  XGB    5.0      0.839845     0.485488          0.070649
# 11     smote  XGB    5.0      0.803118     0.453530          0.058324
#
#     recall@thr_mean  FP_per_1000_mean
# 0          0.980500        845.227723
# 3          0.980500        636.554455
# 6          0.980500        672.673267
# 9          0.980500        826.019802
# 1          0.983860        894.099010
# 4          0.987358        859.683168
# 7          0.988343        883.009901
# 10         0.981277        889.663366
# 2          0.980500        766.415842
# 5          0.980500        646.574257
# 8          0.980500        621.702970
# 11         0.980500        756.594059
# === PRIMARY KPIs (Precision/Recall focus, sorted) ===
#      variant algo  precision@R_mean  recall@thr_mean  FP_per_1000_mean  \
# 8       rose  XGB          0.070649         0.980500        621.702970
# 3   baseline  GBM          0.069466         0.980500        636.554455
# 5   baseline  XGB          0.068188         0.980500        646.574257
# 6       rose  GBM          0.065983         0.980500        672.673267
# 11     smote  XGB          0.058324         0.980500        756.594059
# 2     adasyn  XGB          0.057546         0.980500        766.415842
# 9      smote  GBM          0.053597         0.980500        826.019802
# 0     adasyn  GBM          0.052438         0.980500        845.227723
# 4   baseline   RF          0.052153         0.987358        859.683168
# 7       rose   RF          0.050682         0.988343        883.009901
# 10     smote   RF          0.050111         0.981277        889.663366
# 1     adasyn   RF          0.050037         0.983860        894.099010
#
#     pr_auc_mean  roc_auc_mean  waves
# 8      0.485488      0.839845    5.0
# 3      0.452173      0.832055    5.0
# 5      0.467133      0.831669    5.0
# 6      0.470713      0.829208    5.0
# 11     0.453530      0.803118    5.0
# 2      0.441455      0.801422    5.0
# 9      0.398026      0.758657    5.0
# 0      0.348988      0.736508    5.0
# 4      0.443715      0.787277    5.0
# 7      0.446603      0.788815    5.0
# 10     0.417439      0.731057    5.0
# 1      0.384651      0.733585    5.0
# Saved: out_compare_500\results_by_wave.csv , out_compare_500\summary.csv , out_compare_500\precision_recall_summary.csv
# Confusion matrices saved to: out_compare_500\conf_matrices
# Per-wave progress saved to: out_compare_500\progress_by_wave
# Stability report saved to: out_compare_500\stability_over_waves.csv

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from typing import Dict, Tuple, List, Optional

from sklearn.metrics import roc_auc_score, average_precision_score, confusion_matrix, precision_score, recall_score
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier

try:
    from xgboost import XGBClassifier
    HAS_XGB = True
except Exception:
    HAS_XGB = False

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "4_class_balance").exists():
    parent = PROJECT_ROOT.parent
    if (parent / "4_class_balance").exists():
        PROJECT_ROOT = parent
    else:
        raise RuntimeError(f"Cannot find '4_class_balance' folder from cwd={Path.cwd()}")

# config 
LABEL_COL = "Is_Suspicious"
SCENARIO_COL = "Suspicion Category"
VARIANT_ROOTS: Dict[str, Path] = {
    "baseline": PROJECT_ROOT / "4_class_balance" / "baseline_100",
    "smote":    PROJECT_ROOT / "4_class_balance" / "smote_100",
    "adasyn":   PROJECT_ROOT / "4_class_balance" / "adasyn_100",
    "rose":     PROJECT_ROOT / "4_class_balance" / "rose_100",
}
VARIANT_TRAIN_FILE = {
    "baseline": "train_baseline.csv",
    "smote":    "train_smote.csv",
    "adasyn":   "train_adasyn.csv",
    "rose":     "train_rose.csv",
}

VARIANTS_FOR_DIAG = ["baseline", "smote", "adasyn", "rose"]
ALGOS_FOR_DIAG    = ["GBM", "XGB", "RF"]     

TARGET_RECALL = 0.98
RANDOM_STATE  = 42


# helpers
def list_waves(root: Path) -> List[str]:
    if not root.exists():
        return []
    return sorted([p.name for p in root.iterdir() if p.is_dir()])

def _resolve_train_path(dir_path: Path, variant: str) -> Path:
    primary = dir_path / VARIANT_TRAIN_FILE[variant]
    if primary.exists():
        return primary
    fallback = dir_path / "train.csv"
    if fallback.exists():
        return fallback
    return primary

def load_df(variant: str, wave: str) -> Tuple[pd.DataFrame, pd.DataFrame]:
    root = VARIANT_ROOTS[variant]
    d = root / wave
    train_path = _resolve_train_path(d, variant)
    test_path  = d / "test.csv"
    if not train_path.exists() or not test_path.exists():
        raise FileNotFoundError(f"Missing files for {variant}/{wave} → {train_path} / {test_path}")
    tr = pd.read_csv(train_path)
    te = pd.read_csv(test_path)
    if LABEL_COL not in tr.columns or LABEL_COL not in te.columns:
        raise KeyError(f"Column '{LABEL_COL}' not found in train/test for {variant}/{wave}")
    return tr, te


def make_model(algo: str, y_tr: np.ndarray):
    if algo == "GBM":
        return GradientBoostingClassifier(
            n_estimators=300, learning_rate=0.05, max_depth=3, random_state=RANDOM_STATE
        )
    elif algo == "XGB" and HAS_XGB:
        pos = max(1, int((y_tr == 1).sum()))
        neg = max(1, int((y_tr == 0).sum()))
        spw = neg / pos
        return XGBClassifier(
            n_estimators=400, max_depth=4, learning_rate=0.05,
            subsample=0.8, colsample_bytree=0.8,
            reg_lambda=1.0, random_state=RANDOM_STATE,
            eval_metric="logloss", n_jobs=-1, tree_method="hist",
            scale_pos_weight=spw
        )
    elif algo == "RF":
        return RandomForestClassifier(
            n_estimators=300, max_depth=None, min_samples_leaf=1,
            class_weight="balanced", random_state=RANDOM_STATE, n_jobs=-1
        )
    else:
        raise RuntimeError("Unsupported algo or xgboost not installed.")


def threshold_for_recall(y_true: np.ndarray, scores: np.ndarray, target: float):
    order = np.argsort(-scores)
    y_sorted = y_true[order]
    s_sorted = scores[order]
    P = int(y_true.sum())
    if P == 0:
        tn = int((y_true == 0).sum())
        return 1.0, {"precision": 0.0, "recall": 0.0, "tp": 0, "fp": 0, "tn": tn, "fn": 0}
    tp_cum = np.cumsum(y_sorted)
    fp_cum = np.cumsum(1 - y_sorted)
    recall_cum = tp_cum / (P + 1e-12)
    idx = np.where(recall_cum >= target)[0]
    if len(idx) == 0:
        thr = s_sorted[-1] - 1e-12
        pred = np.ones_like(y_true)
    else:
        k = int(idx[0])
        thr = s_sorted[k]
        pred = (scores >= thr).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, pred, labels=[0,1]).ravel()
    prec = tp / max(1, tp + fp)
    rec  = tp / max(1, P)
    return float(thr), {"precision": float(prec), "recall": float(rec), "tp": int(tp), "fp": int(fp), "tn": int(tn), "fn": int(fn)}

def make_X(df: pd.DataFrame, feature_cols: Optional[List[str]] = None) -> Tuple[np.ndarray, List[str]]:
    drop = [LABEL_COL]
    if SCENARIO_COL in df.columns:
        drop.append(SCENARIO_COL)

    if feature_cols is None:
        feature_cols = [c for c in df.columns if c not in drop]
    X = df.reindex(columns=feature_cols, fill_value=0).to_numpy()
    return X, feature_cols

# val-based threshold
def val_threshold_check(variant: str, algo: str, wave: str, val_frac: float = 0.2):
    print(f"\n[VAL CHECK] variant={variant}, algo={algo}, wave={wave}, val_frac={val_frac}")
    tr, te = load_df(variant, wave)

    # Split train chronologically
    n = len(tr)
    n_val = max(1, int(n * val_frac))
    tr_core = tr.iloc[:-n_val].copy()
    val     = tr.iloc[-n_val:].copy()

    print(f"train_core: {len(tr_core)} rows, val: {len(val)} rows, test: {len(te)} rows")

    X_core, feat_cols = make_X(tr_core, None)
    y_core = tr_core[LABEL_COL].astype(int).to_numpy()

    X_val, _  = make_X(val, feat_cols)
    y_val  = val[LABEL_COL].astype(int).to_numpy()

    X_test, _ = make_X(te, feat_cols)
    y_test = te[LABEL_COL].astype(int).to_numpy()

    model = make_model(algo, y_core)

    sw = None
    if algo == "GBM":
        n_pos = max(1, int((y_core == 1).sum()))
        n_neg = max(1, int((y_core == 0).sum()))
        w_pos = n_neg / (n_pos + n_neg)
        w_neg = n_pos / (n_pos + n_neg)
        sw = np.where(y_core == 1, w_pos, w_neg)

    model.fit(X_core, y_core, sample_weight=sw) if sw is not None else model.fit(X_core, y_core)

    if hasattr(model, "predict_proba"):
        p_val  = model.predict_proba(X_val)[:, 1]
        p_test = model.predict_proba(X_test)[:, 1]
    else:
        dec_val  = model.decision_function(X_val)
        dec_test = model.decision_function(X_test)
        p_val  = (dec_val  - dec_val.min())  / (dec_val.max()  - dec_val.min()  + 1e-12)
        p_test = (dec_test - dec_test.min()) / (dec_test.max() - dec_test.min() + 1e-12)

    thr_val, at_val = threshold_for_recall(y_val, p_val, TARGET_RECALL)
    pred_test = (p_test >= thr_val).astype(int)

    tn, fp, fn, tp = confusion_matrix(y_test, pred_test, labels=[0,1]).ravel()
    prec_test = tp / max(1, tp + fp)
    rec_test  = tp / max(1, int((y_test == 1).sum()))
    fp_per_1000 = fp / max(1, len(y_test)) * 1000.0

    roc_test = roc_auc_score(y_test, p_test)
    prc_test = average_precision_score(y_test, p_test)

    print(f"VAL:  thr={thr_val:.4f}, recall={at_val['recall']:.3f}, precision={at_val['precision']:.3f}")
    print(f"TEST: recall={rec_test:.3f}, precision={prec_test:.3f}, FP={fp}, TP={tp}, TN={tn}, FN={fn}, FP/1000={fp_per_1000:.3f}")
    print(f"      ROC-AUC={roc_test:.4f}, PR-AUC={prc_test:.4f}")

# cross-wave generalisation
def cross_wave_generalisation(variant: str, algo: str, wave_train: str, wave_test: str):
    print(f"\n[CROSS-WAVE] variant={variant}, algo={algo}, train_wave={wave_train}, test_wave={wave_test}")
    tr, _ = load_df(variant, wave_train)
    _, te = load_df(variant, wave_test)

    X_tr, feat_cols = make_X(tr, None)
    y_tr = tr[LABEL_COL].astype(int).to_numpy()

    X_te, _ = make_X(te, feat_cols)
    y_te = te[LABEL_COL].astype(int).to_numpy()

    model = make_model(algo, y_tr)
    sw = None
    if algo == "GBM":
        n_pos = max(1, int((y_tr == 1).sum()))
        n_neg = max(1, int((y_tr == 0).sum()))
        w_pos = n_neg / (n_pos + n_neg)
        w_neg = n_pos / (n_pos + n_neg)
        sw = np.where(y_tr == 1, w_pos, w_neg)

    model.fit(X_tr, y_tr, sample_weight=sw) if sw is not None else model.fit(X_tr, y_tr)

    if hasattr(model, "predict_proba"):
        p = model.predict_proba(X_te)[:, 1]
    else:
        dec = model.decision_function(X_te)
        p = (dec - dec.min()) / (dec.max() - dec.min() + 1e-12)

    try:
        roc = roc_auc_score(y_te, p)
    except ValueError:
        roc = np.nan 

    try:
        prc = average_precision_score(y_te, p)
    except ValueError:
        prc = np.nan
    
    pred05 = (p >= 0.5).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_te, pred05, labels=[0,1]).ravel()
    prec = tp / max(1, tp + fp)
    rec  = tp / max(1, int((y_te == 1).sum()))

    print(f"AUCs on TEST of {wave_test}: ROC-AUC={roc:.4f}, PR-AUC={prc:.4f}")
    print(f"Threshold=0.5 → recall={rec:.3f}, precision={prec:.3f}, TP={tp}, FP={fp}, TN={tn}, FN={fn}")

def metrics_at_threshold(y_true: np.ndarray, scores: np.ndarray, thr: float):
    pred = (scores >= thr).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, pred, labels=[0, 1]).ravel()
    P = int(y_true.sum())
    prec = tp / max(1, tp + fp)
    rec = tp / max(1, P)
    return {"precision": float(prec), "recall": float(rec), "tp": int(tp), "fp": int(fp), "tn": int(tn), "fn": int(fn)}

def predict_scores(model, X: np.ndarray) -> np.ndarray:
    if hasattr(model, "predict_proba"):
        return model.predict_proba(X)[:, 1]
    dec = model.decision_function(X)
    return (dec - dec.min()) / (dec.max() - dec.min() + 1e-12)

# feature ablation
def feature_ablation(variant: str, algo: str, wave: str, drop_cols: Optional[List[str]] = None):
    if not drop_cols:
        print("\n[ABLATION] No columns specified, skipping.")
        return
    print(f"\n[ABLATION] variant={variant}, algo={algo}, wave={wave}, dropping={drop_cols}")
    tr, te = load_df(variant, wave)

    keep_tr = tr.drop(columns=[c for c in drop_cols if c in tr.columns], errors="ignore")
    keep_te = te.drop(columns=[c for c in drop_cols if c in te.columns], errors="ignore")

    X_tr, feat_cols = make_X(keep_tr, None)
    y_tr = keep_tr[LABEL_COL].astype(int).to_numpy()

    X_te, _ = make_X(keep_te, feat_cols)
    y_te = keep_te[LABEL_COL].astype(int).to_numpy()

    model = make_model(algo, y_tr)
    sw = None
    if algo == "GBM":
        n_pos = max(1, int((y_tr == 1).sum()))
        n_neg = max(1, int((y_tr == 0).sum()))
        w_pos = n_neg / (n_pos + n_neg)
        w_neg = n_pos / (n_pos + n_neg)
        sw = np.where(y_tr == 1, w_pos, w_neg)

    model.fit(X_tr, y_tr, sample_weight=sw) if sw is not None else model.fit(X_tr, y_tr)

    if hasattr(model, "predict_proba"):
        p = model.predict_proba(X_te)[:, 1]
    else:
        dec = model.decision_function(X_te)
        p = (dec - dec.min()) / (dec.max() - dec.min() + 1e-12)

    p = predict_scores(model, X_te)
    p_tr = predict_scores(model, X_tr)

    roc = roc_auc_score(y_te, p)
    prc = average_precision_score(y_te, p)

    thr, _ = threshold_for_recall(y_tr, p_tr, TARGET_RECALL)
    at = metrics_at_threshold(y_te, p, thr)

    print(f"After dropping features: ROC-AUC={roc:.4f}, PR-AUC={prc:.4f}")
    print(f"Recall≈{at['recall']:.3f}, Precision≈{at['precision']:.3f} at threshold chosen for Recall≥{TARGET_RECALL}")

# permutation
def permutation_test(variant: str, algo: str, wave: str, n_repeats: int = 3, random_state: int = 42):
    print(f"\n[PERMUTATION TEST] variant={variant}, algo={algo}, wave={wave}, repeats={n_repeats}")
    rng = np.random.default_rng(random_state)
    tr, te = load_df(variant, wave)

    X_tr, feat_cols = make_X(tr, None)
    y_tr = tr[LABEL_COL].astype(int).to_numpy()

    X_te, _ = make_X(te, feat_cols)
    y_te = te[LABEL_COL].astype(int).to_numpy()

    aucs_roc = []
    aucs_pr  = []

    for i in range(n_repeats):
        y_perm = rng.permutation(y_tr)
        model = make_model(algo, y_perm)

        sw = None
        if algo == "GBM":
            n_pos = max(1, int((y_perm == 1).sum()))
            n_neg = max(1, int((y_perm == 0).sum()))
            w_pos = n_neg / (n_pos + n_neg)
            w_neg = n_pos / (n_pos + n_neg)
            sw = np.where(y_perm == 1, w_pos, w_neg)

        model.fit(X_tr, y_perm, sample_weight=sw) if sw is not None else model.fit(X_tr, y_perm)

        if hasattr(model, "predict_proba"):
            p = model.predict_proba(X_te)[:, 1]
        else:
            dec = model.decision_function(X_te)
            p = (dec - dec.min()) / (dec.max() - dec.min() + 1e-12)

        roc = roc_auc_score(y_te, p)
        prc = average_precision_score(y_te, p)
        aucs_roc.append(roc)
        aucs_pr.append(prc)
        print(f"  repeat {i+1}/{n_repeats}: ROC-AUC={roc:.4f}, PR-AUC={prc:.4f}")

    print(f"Random-label ROC-AUC: mean={np.mean(aucs_roc):.4f}, std={np.std(aucs_roc):.4f}")
    print(f"Random-label PR-AUC : mean={np.mean(aucs_pr):.4f}, std={np.std(aucs_pr):.4f}")

# driver
def run_all_diagnostics():
    for variant in VARIANTS_FOR_DIAG:
        waves = list_waves(VARIANT_ROOTS[variant])
        if not waves:
            print(f"\n[SKIP] No waves found for variant={variant} in", VARIANT_ROOTS[variant])
            continue

        w1 = waves[0]      
        wk = waves[-1]     

        for algo in ALGOS_FOR_DIAG:
            if algo == "XGB" and not HAS_XGB:
                print(f"\n[SKIP] XGB not available for variant={variant}")
                continue

            print("\n" + "="*80)
            print(f"[RUN] Diagnostics for variant={variant}, algo={algo}")
            print("="*80)

            # Threshold
            val_threshold_check(variant, algo, w1, val_frac=0.2)

            # Cross-wave
            if len(waves) > 1:
                cross_wave_generalisation(variant, algo, w1, wk)
                cross_wave_generalisation(variant, algo, wk, w1)

            # Permutation test
            permutation_test(variant, algo, w1, n_repeats=3, random_state=RANDOM_STATE)
run_all_diagnostics()
# Out:
# ================================================================================
# [RUN] Diagnostics for variant=baseline, algo=GBM
# ================================================================================
#
# [VAL CHECK] variant=baseline, algo=GBM, wave=synthetic_transactions_structured_100_1, val_frac=0.2
# train_core: 6464 rows, val: 1616 rows, test: 2020 rows
# VAL:  thr=0.0010, recall=1.000, precision=0.400
# TEST: recall=1.000, precision=0.686, FP=16, TP=35, TN=1969, FN=0, FP/1000=7.921
#       ROC-AUC=1.0000, PR-AUC=0.9992
#
# [CROSS-WAVE] variant=baseline, algo=GBM, train_wave=synthetic_transactions_structured_100_1, test_wave=synthetic_transactions_structured_100_5
# AUCs on TEST of synthetic_transactions_structured_100_5: ROC-AUC=0.9394, PR-AUC=0.7418
# Threshold=0.5 → recall=0.467, precision=0.875, TP=14, FP=2, TN=1988, FN=16
#
# [CROSS-WAVE] variant=baseline, algo=GBM, train_wave=synthetic_transactions_structured_100_5, test_wave=synthetic_transactions_structured_100_1
# AUCs on TEST of synthetic_transactions_structured_100_1: ROC-AUC=0.9857, PR-AUC=0.6302
# Threshold=0.5 → recall=0.286, precision=0.400, TP=10, FP=15, TN=1970, FN=25
#
# [PERMUTATION TEST] variant=baseline, algo=GBM, wave=synthetic_transactions_structured_100_1, repeats=3
#   repeat 1/3: ROC-AUC=0.4061, PR-AUC=0.0143
#   repeat 2/3: ROC-AUC=0.4472, PR-AUC=0.0213
#   repeat 3/3: ROC-AUC=0.2702, PR-AUC=0.0112
# Random-label ROC-AUC: mean=0.3745, std=0.0756
# Random-label PR-AUC : mean=0.0156, std=0.0042
#
# ================================================================================
# [RUN] Diagnostics for variant=baseline, algo=XGB
# ================================================================================
#
# [VAL CHECK] variant=baseline, algo=XGB, wave=synthetic_transactions_structured_100_1, val_frac=0.2
# train_core: 6464 rows, val: 1616 rows, test: 2020 rows
# VAL:  thr=0.0007, recall=1.000, precision=0.129
# TEST: recall=1.000, precision=0.294, FP=84, TP=35, TN=1901, FN=0, FP/1000=41.584
#       ROC-AUC=1.0000, PR-AUC=0.9984
#
# [CROSS-WAVE] variant=baseline, algo=XGB, train_wave=synthetic_transactions_structured_100_1, test_wave=synthetic_transactions_structured_100_5
# AUCs on TEST of synthetic_transactions_structured_100_5: ROC-AUC=0.9823, PR-AUC=0.6155
# Threshold=0.5 → recall=0.433, precision=0.929, TP=13, FP=1, TN=1989, FN=17
#
# [CROSS-WAVE] variant=baseline, algo=XGB, train_wave=synthetic_transactions_structured_100_5, test_wave=synthetic_transactions_structured_100_1
# AUCs on TEST of synthetic_transactions_structured_100_1: ROC-AUC=0.9948, PR-AUC=0.7942
# Threshold=0.5 → recall=0.286, precision=1.000, TP=10, FP=0, TN=1985, FN=25
#
# [PERMUTATION TEST] variant=baseline, algo=XGB, wave=synthetic_transactions_structured_100_1, repeats=3
#   repeat 1/3: ROC-AUC=0.4113, PR-AUC=0.0140
#   repeat 2/3: ROC-AUC=0.5108, PR-AUC=0.0177
#   repeat 3/3: ROC-AUC=0.4343, PR-AUC=0.0152
# Random-label ROC-AUC: mean=0.4522, std=0.0425
# Random-label PR-AUC : mean=0.0156, std=0.0015
#
# ================================================================================
# [RUN] Diagnostics for variant=baseline, algo=RF
# ================================================================================
#
# [VAL CHECK] variant=baseline, algo=RF, wave=synthetic_transactions_structured_100_1, val_frac=0.2
# train_core: 6464 rows, val: 1616 rows, test: 2020 rows
# VAL:  thr=0.0200, recall=1.000, precision=0.286
# TEST: recall=1.000, precision=0.538, FP=30, TP=35, TN=1955, FN=0, FP/1000=14.851
#       ROC-AUC=0.9998, PR-AUC=0.9903
#
# [CROSS-WAVE] variant=baseline, algo=RF, train_wave=synthetic_transactions_structured_100_1, test_wave=synthetic_transactions_structured_100_5
# AUCs on TEST of synthetic_transactions_structured_100_5: ROC-AUC=0.9886, PR-AUC=0.8490
# Threshold=0.5 → recall=0.433, precision=1.000, TP=13, FP=0, TN=1990, FN=17
#
# [CROSS-WAVE] variant=baseline, algo=RF, train_wave=synthetic_transactions_structured_100_5, test_wave=synthetic_transactions_structured_100_1
# AUCs on TEST of synthetic_transactions_structured_100_1: ROC-AUC=0.9950, PR-AUC=0.8674
# Threshold=0.5 → recall=0.286, precision=1.000, TP=10, FP=0, TN=1985, FN=25
#
# [PERMUTATION TEST] variant=baseline, algo=RF, wave=synthetic_transactions_structured_100_1, repeats=3
#   repeat 1/3: ROC-AUC=0.5014, PR-AUC=0.0185
#   repeat 2/3: ROC-AUC=0.5942, PR-AUC=0.0215
#   repeat 3/3: ROC-AUC=0.4334, PR-AUC=0.0155
# Random-label ROC-AUC: mean=0.5096, std=0.0659
# Random-label PR-AUC : mean=0.0185, std=0.0024
#
# ================================================================================
# [RUN] Diagnostics for variant=smote, algo=GBM
# ================================================================================
#
# [VAL CHECK] variant=smote, algo=GBM, wave=synthetic_transactions_structured_100_1, val_frac=0.2
# train_core: 9618 rows, val: 2404 rows, test: 2020 rows
# VAL:  thr=0.9995, recall=0.980, precision=1.000
# TEST: recall=0.571, precision=1.000, FP=0, TP=20, TN=1985, FN=15, FP/1000=0.000
#       ROC-AUC=1.0000, PR-AUC=0.9992
#
# [CROSS-WAVE] variant=smote, algo=GBM, train_wave=synthetic_transactions_structured_100_1, test_wave=synthetic_transactions_structured_100_5
# AUCs on TEST of synthetic_transactions_structured_100_5: ROC-AUC=0.9500, PR-AUC=0.8131
# Threshold=0.5 → recall=0.800, precision=0.857, TP=24, FP=4, TN=1986, FN=6
#
# [CROSS-WAVE] variant=smote, algo=GBM, train_wave=synthetic_transactions_structured_100_5, test_wave=synthetic_transactions_structured_100_1
# AUCs on TEST of synthetic_transactions_structured_100_1: ROC-AUC=0.9822, PR-AUC=0.5872
# Threshold=0.5 → recall=0.286, precision=1.000, TP=10, FP=0, TN=1985, FN=25
#
# [PERMUTATION TEST] variant=smote, algo=GBM, wave=synthetic_transactions_structured_100_1, repeats=3
#   repeat 1/3: ROC-AUC=0.4770, PR-AUC=0.0182
#   repeat 2/3: ROC-AUC=0.4890, PR-AUC=0.0175
#   repeat 3/3: ROC-AUC=0.3919, PR-AUC=0.0141
# Random-label ROC-AUC: mean=0.4527, std=0.0432
# Random-label PR-AUC : mean=0.0166, std=0.0018
#
# ================================================================================
# [RUN] Diagnostics for variant=smote, algo=XGB
# ================================================================================
#
# [VAL CHECK] variant=smote, algo=XGB, wave=synthetic_transactions_structured_100_1, val_frac=0.2
# train_core: 9618 rows, val: 2404 rows, test: 2020 rows
# VAL:  thr=0.9985, recall=0.980, precision=1.000
# TEST: recall=0.800, precision=1.000, FP=0, TP=28, TN=1985, FN=7, FP/1000=0.000
#       ROC-AUC=0.9999, PR-AUC=0.9967
#
# [CROSS-WAVE] variant=smote, algo=XGB, train_wave=synthetic_transactions_structured_100_1, test_wave=synthetic_transactions_structured_100_5
# AUCs on TEST of synthetic_transactions_structured_100_5: ROC-AUC=0.9954, PR-AUC=0.8874
# Threshold=0.5 → recall=0.800, precision=0.960, TP=24, FP=1, TN=1989, FN=6
#
# [CROSS-WAVE] variant=smote, algo=XGB, train_wave=synthetic_transactions_structured_100_5, test_wave=synthetic_transactions_structured_100_1
# AUCs on TEST of synthetic_transactions_structured_100_1: ROC-AUC=0.9915, PR-AUC=0.6780
# Threshold=0.5 → recall=0.286, precision=1.000, TP=10, FP=0, TN=1985, FN=25
#
# [PERMUTATION TEST] variant=smote, algo=XGB, wave=synthetic_transactions_structured_100_1, repeats=3
#   repeat 1/3: ROC-AUC=0.6552, PR-AUC=0.0302
#   repeat 2/3: ROC-AUC=0.5110, PR-AUC=0.0170
#   repeat 3/3: ROC-AUC=0.4011, PR-AUC=0.0137
# Random-label ROC-AUC: mean=0.5224, std=0.1041
# Random-label PR-AUC : mean=0.0203, std=0.0071
#
# ================================================================================
# [RUN] Diagnostics for variant=smote, algo=RF
# ================================================================================
#
# [VAL CHECK] variant=smote, algo=RF, wave=synthetic_transactions_structured_100_1, val_frac=0.2
# train_core: 9618 rows, val: 2404 rows, test: 2020 rows
# VAL:  thr=0.9600, recall=0.981, precision=1.000
# TEST: recall=0.000, precision=0.000, FP=0, TP=0, TN=1985, FN=35, FP/1000=0.000
#       ROC-AUC=0.9999, PR-AUC=0.9918
#
# [CROSS-WAVE] variant=smote, algo=RF, train_wave=synthetic_transactions_structured_100_1, test_wave=synthetic_transactions_structured_100_5
# AUCs on TEST of synthetic_transactions_structured_100_5: ROC-AUC=0.9820, PR-AUC=0.8108
# Threshold=0.5 → recall=0.433, precision=1.000, TP=13, FP=0, TN=1990, FN=17
#
# [CROSS-WAVE] variant=smote, algo=RF, train_wave=synthetic_transactions_structured_100_5, test_wave=synthetic_transactions_structured_100_1
# AUCs on TEST of synthetic_transactions_structured_100_1: ROC-AUC=0.9960, PR-AUC=0.8526
# Threshold=0.5 → recall=0.371, precision=1.000, TP=13, FP=0, TN=1985, FN=22
#
# [PERMUTATION TEST] variant=smote, algo=RF, wave=synthetic_transactions_structured_100_1, repeats=3
#   repeat 1/3: ROC-AUC=0.6432, PR-AUC=0.0233
#   repeat 2/3: ROC-AUC=0.5623, PR-AUC=0.0187
#   repeat 3/3: ROC-AUC=0.6313, PR-AUC=0.0222
# Random-label ROC-AUC: mean=0.6123, std=0.0356
# Random-label PR-AUC : mean=0.0214, std=0.0020
#
# ================================================================================
# [RUN] Diagnostics for variant=adasyn, algo=GBM
# ================================================================================
#
# [VAL CHECK] variant=adasyn, algo=GBM, wave=synthetic_transactions_structured_100_1, val_frac=0.2
# train_core: 9618 rows, val: 2404 rows, test: 2020 rows
# VAL:  thr=0.0839, recall=0.985, precision=1.000
# TEST: recall=0.971, precision=0.971, FP=1, TP=34, TN=1984, FN=1, FP/1000=0.495
#       ROC-AUC=1.0000, PR-AUC=0.9992
#
# [CROSS-WAVE] variant=adasyn, algo=GBM, train_wave=synthetic_transactions_structured_100_1, test_wave=synthetic_transactions_structured_100_5
# AUCs on TEST of synthetic_transactions_structured_100_5: ROC-AUC=0.9478, PR-AUC=0.8120
# Threshold=0.5 → recall=0.800, precision=0.889, TP=24, FP=3, TN=1987, FN=6
#
# [CROSS-WAVE] variant=adasyn, algo=GBM, train_wave=synthetic_transactions_structured_100_5, test_wave=synthetic_transactions_structured_100_1
# AUCs on TEST of synthetic_transactions_structured_100_1: ROC-AUC=0.9888, PR-AUC=0.6274
# Threshold=0.5 → recall=0.286, precision=1.000, TP=10, FP=0, TN=1985, FN=25
#
# [PERMUTATION TEST] variant=adasyn, algo=GBM, wave=synthetic_transactions_structured_100_1, repeats=3
#   repeat 1/3: ROC-AUC=0.4286, PR-AUC=0.0142
#   repeat 2/3: ROC-AUC=0.6883, PR-AUC=0.1379
#   repeat 3/3: ROC-AUC=0.4407, PR-AUC=0.0154
# Random-label ROC-AUC: mean=0.5192, std=0.1197
# Random-label PR-AUC : mean=0.0558, std=0.0580
#
# ================================================================================
# [RUN] Diagnostics for variant=adasyn, algo=XGB
# ================================================================================
#
# [VAL CHECK] variant=adasyn, algo=XGB, wave=synthetic_transactions_structured_100_1, val_frac=0.2
# train_core: 9618 rows, val: 2404 rows, test: 2020 rows
# VAL:  thr=0.8148, recall=0.980, precision=1.000
# TEST: recall=0.886, precision=1.000, FP=0, TP=31, TN=1985, FN=4, FP/1000=0.000
#       ROC-AUC=1.0000, PR-AUC=0.9992
#
# [CROSS-WAVE] variant=adasyn, algo=XGB, train_wave=synthetic_transactions_structured_100_1, test_wave=synthetic_transactions_structured_100_5
# AUCs on TEST of synthetic_transactions_structured_100_5: ROC-AUC=0.9958, PR-AUC=0.8899
# Threshold=0.5 → recall=0.800, precision=1.000, TP=24, FP=0, TN=1990, FN=6
#
# [CROSS-WAVE] variant=adasyn, algo=XGB, train_wave=synthetic_transactions_structured_100_5, test_wave=synthetic_transactions_structured_100_1
# AUCs on TEST of synthetic_transactions_structured_100_1: ROC-AUC=0.9939, PR-AUC=0.7895
# Threshold=0.5 → recall=0.286, precision=1.000, TP=10, FP=0, TN=1985, FN=25
#
# [PERMUTATION TEST] variant=adasyn, algo=XGB, wave=synthetic_transactions_structured_100_1, repeats=3
#   repeat 1/3: ROC-AUC=0.4851, PR-AUC=0.0177
#   repeat 2/3: ROC-AUC=0.5411, PR-AUC=0.0331
#   repeat 3/3: ROC-AUC=0.3561, PR-AUC=0.0130
# Random-label ROC-AUC: mean=0.4608, std=0.0774
# Random-label PR-AUC : mean=0.0213, std=0.0086
#
# ================================================================================
# [RUN] Diagnostics for variant=adasyn, algo=RF
# ================================================================================
#
# [VAL CHECK] variant=adasyn, algo=RF, wave=synthetic_transactions_structured_100_1, val_frac=0.2
# train_core: 9618 rows, val: 2404 rows, test: 2020 rows
# VAL:  thr=0.3500, recall=0.980, precision=1.000
# TEST: recall=0.829, precision=1.000, FP=0, TP=29, TN=1985, FN=6, FP/1000=0.000
#       ROC-AUC=0.9998, PR-AUC=0.9907
#
# [CROSS-WAVE] variant=adasyn, algo=RF, train_wave=synthetic_transactions_structured_100_1, test_wave=synthetic_transactions_structured_100_5
# AUCs on TEST of synthetic_transactions_structured_100_5: ROC-AUC=0.9832, PR-AUC=0.8071
# Threshold=0.5 → recall=0.433, precision=1.000, TP=13, FP=0, TN=1990, FN=17
#
# [CROSS-WAVE] variant=adasyn, algo=RF, train_wave=synthetic_transactions_structured_100_5, test_wave=synthetic_transactions_structured_100_1
# AUCs on TEST of synthetic_transactions_structured_100_1: ROC-AUC=0.9970, PR-AUC=0.8860
# Threshold=0.5 → recall=0.286, precision=1.000, TP=10, FP=0, TN=1985, FN=25
#
# [PERMUTATION TEST] variant=adasyn, algo=RF, wave=synthetic_transactions_structured_100_1, repeats=3
#   repeat 1/3: ROC-AUC=0.6801, PR-AUC=0.0278
#   repeat 2/3: ROC-AUC=0.6754, PR-AUC=0.0260
#   repeat 3/3: ROC-AUC=0.5989, PR-AUC=0.0212
# Random-label ROC-AUC: mean=0.6514, std=0.0372
# Random-label PR-AUC : mean=0.0250, std=0.0028
#
# ================================================================================
# [RUN] Diagnostics for variant=rose, algo=GBM
# ================================================================================
#
# [VAL CHECK] variant=rose, algo=GBM, wave=synthetic_transactions_structured_100_1, val_frac=0.2
# train_core: 12824 rows, val: 3206 rows, test: 2020 rows
# VAL:  thr=0.9996, recall=0.980, precision=1.000
# TEST: recall=0.000, precision=0.000, FP=0, TP=0, TN=1985, FN=35, FP/1000=0.000
#       ROC-AUC=0.9999, PR-AUC=0.9969
#
# [CROSS-WAVE] variant=rose, algo=GBM, train_wave=synthetic_transactions_structured_100_1, test_wave=synthetic_transactions_structured_100_5
# AUCs on TEST of synthetic_transactions_structured_100_5: ROC-AUC=0.8811, PR-AUC=0.5704
# Threshold=0.5 → recall=0.800, precision=0.116, TP=24, FP=183, TN=1807, FN=6
#
# [CROSS-WAVE] variant=rose, algo=GBM, train_wave=synthetic_transactions_structured_100_5, test_wave=synthetic_transactions_structured_100_1
# AUCs on TEST of synthetic_transactions_structured_100_1: ROC-AUC=0.9674, PR-AUC=0.4723
# Threshold=0.5 → recall=0.371, precision=0.171, TP=13, FP=63, TN=1922, FN=22
#
# [PERMUTATION TEST] variant=rose, algo=GBM, wave=synthetic_transactions_structured_100_1, repeats=3
#   repeat 1/3: ROC-AUC=0.6390, PR-AUC=0.0376
#   repeat 2/3: ROC-AUC=0.6567, PR-AUC=0.0288
#   repeat 3/3: ROC-AUC=0.3656, PR-AUC=0.0136
# Random-label ROC-AUC: mean=0.5538, std=0.1332
# Random-label PR-AUC : mean=0.0267, std=0.0099
#
# ================================================================================
# [RUN] Diagnostics for variant=rose, algo=XGB
# ================================================================================
#
# [VAL CHECK] variant=rose, algo=XGB, wave=synthetic_transactions_structured_100_1, val_frac=0.2
# train_core: 12824 rows, val: 3206 rows, test: 2020 rows
# VAL:  thr=0.9992, recall=0.980, precision=1.000
# TEST: recall=0.086, precision=1.000, FP=0, TP=3, TN=1985, FN=32, FP/1000=0.000
#       ROC-AUC=1.0000, PR-AUC=0.9992
#
# [CROSS-WAVE] variant=rose, algo=XGB, train_wave=synthetic_transactions_structured_100_1, test_wave=synthetic_transactions_structured_100_5
# AUCs on TEST of synthetic_transactions_structured_100_5: ROC-AUC=0.9770, PR-AUC=0.7322
# Threshold=0.5 → recall=0.800, precision=0.114, TP=24, FP=187, TN=1803, FN=6
#
# [CROSS-WAVE] variant=rose, algo=XGB, train_wave=synthetic_transactions_structured_100_5, test_wave=synthetic_transactions_structured_100_1
# AUCs on TEST of synthetic_transactions_structured_100_1: ROC-AUC=0.9726, PR-AUC=0.4902
# Threshold=0.5 → recall=1.000, precision=0.199, TP=35, FP=141, TN=1844, FN=0
#
# [PERMUTATION TEST] variant=rose, algo=XGB, wave=synthetic_transactions_structured_100_1, repeats=3
#   repeat 1/3: ROC-AUC=0.5465, PR-AUC=0.0196
#   repeat 2/3: ROC-AUC=0.7276, PR-AUC=0.0340
#   repeat 3/3: ROC-AUC=0.4395, PR-AUC=0.0161
# Random-label ROC-AUC: mean=0.5712, std=0.1189
# Random-label PR-AUC : mean=0.0232, std=0.0078
#
# ================================================================================
# [RUN] Diagnostics for variant=rose, algo=RF
# ================================================================================
#
# [VAL CHECK] variant=rose, algo=RF, wave=synthetic_transactions_structured_100_1, val_frac=0.2
# train_core: 12824 rows, val: 3206 rows, test: 2020 rows
# VAL:  thr=0.9933, recall=0.983, precision=1.000
# TEST: recall=0.000, precision=0.000, FP=0, TP=0, TN=1985, FN=35, FP/1000=0.000
#       ROC-AUC=1.0000, PR-AUC=0.9985
#
# [CROSS-WAVE] variant=rose, algo=RF, train_wave=synthetic_transactions_structured_100_1, test_wave=synthetic_transactions_structured_100_5
# AUCs on TEST of synthetic_transactions_structured_100_5: ROC-AUC=0.9601, PR-AUC=0.5315
# Threshold=0.5 → recall=1.000, precision=0.015, TP=30, FP=1990, TN=0, FN=0
#
# [CROSS-WAVE] variant=rose, algo=RF, train_wave=synthetic_transactions_structured_100_5, test_wave=synthetic_transactions_structured_100_1
# AUCs on TEST of synthetic_transactions_structured_100_1: ROC-AUC=0.9938, PR-AUC=0.8818
# Threshold=0.5 → recall=1.000, precision=0.018, TP=35, FP=1946, TN=39, FN=0
#
# [PERMUTATION TEST] variant=rose, algo=RF, wave=synthetic_transactions_structured_100_1, repeats=3
#   repeat 1/3: ROC-AUC=0.6101, PR-AUC=0.0226
#   repeat 2/3: ROC-AUC=0.4469, PR-AUC=0.0159
#   repeat 3/3: ROC-AUC=0.4298, PR-AUC=0.0144
# Random-label ROC-AUC: mean=0.4956, std=0.0812
# Random-label PR-AUC : mean=0.0176, std=0.0036
